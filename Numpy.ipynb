# %% [markdown]
# ### **NUMPY**

# %%
import numpy as np

# %% [markdown]
# Creating an array

# %%
a = np.array([1, 2, 3])
a
# Out:
# array([1, 2, 3])

# %% [markdown]
# Operations

# %%
a + 5
# Out:
# array([6, 7, 8])

# %%
a * 2
# Out:
# array([2, 4, 6])

# %%
a ** 2
# Out:
# array([1, 4, 9])

# %% [markdown]
# Accessing Data

# %%
a[0]
# Out:
# np.int64(1)

# %%
a[-1]
# Out:
# np.int64(3)

# %%
a[0:2]
# Out:
# array([1, 2])

# %% [markdown]
# ### 2D Array

# %%
matrix = np.array([[1,2,3],
                   [4,5,6]])

matrix[0,1]
# Out:
# np.int64(2)

# %%
matrix[:,1]
# Out:
# array([2, 5])

# %%
matrix[1,:]
# Out:
# array([4, 5, 6])

# %% [markdown]
# ### SHAPE and DIMENSIONS

# %%
a.shape
# Out:
# (3,)

# %%
a.ndim #dimensions
# Out:
# 1

# %% [markdown]
# ### Aggregation Functions

# %%
np.sum(a)
# Out:
# np.int64(6)

# %%
np.mean(a)
# Out:
# np.float64(2.0)

# %%
np.min(a)
# Out:
# np.int64(1)

# %%
np.max(a)
# Out:
# np.int64(3)

# %%
np.std(a) # standard deviation (how spread the numbers are)
# Out:
# np.float64(0.816496580927726)

# %%
np.mean(matrix, axis=0)
# Out:
# array([2.5, 3.5, 4.5])

# %%
a = np.array([10, 20, 30, 40])

a > 20
# Out:
# array([False, False,  True,  True])

# %%
a[a > 20]
# Out:
# array([30, 40])

# %% [markdown]
# ### Random numbers

# %%
np.random.rand(3)
np.random.randint(1, 10, 5)
# Out:
# array([8, 4, 9, 4, 8])
